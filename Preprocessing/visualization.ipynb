# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/nguye/SteamCrawler/SteamCrawler/SteamGames.csv')

# %%
df.nunique()
# Out:
# Appid                29789
# Name                 29779
# Type                     6
# ReleaseDate           4416
# Genres                1185
# Developers           14777
# Publishers           11238
# Description          29651
# price                  452
# Thumbnail            29786
# Tags                 24682
# ReviewScore             10
# PositiveReview        3766
# NegativeReview        1668
# OsRequirement         4027
# MemoryRequirement      399
# CpuRequirement        8430
# Rank                 16719
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29931 entries, 0 to 29930
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Appid              29931 non-null  int64
#  1   Name               29931 non-null  object
#  2   Type               29931 non-null  object
#  3   ReleaseDate        29917 non-null  object
#  4   Genres             29518 non-null  object
#  5   Developers         29905 non-null  object
#  6   Publishers         28886 non-null  object
#  7   Description        29879 non-null  object
#  8   price              29931 non-null  object
#  9   Thumbnail          29931 non-null  object
#  10  Tags               28317 non-null  object
#  11  ReviewScore        29931 non-null  int64
#  12  PositiveReview     29931 non-null  int64
#  13  NegativeReview     29931 non-null  int64
#  14  OsRequirement      26994 non-null  object
#  15  MemoryRequirement  25947 non-null  object
#  16  CpuRequirement     26072 non-null  object
#  17  Rank               29931 non-null  int64
# dtypes: int64(5), object(13)
# memory usage: 4.1+ MB

# %%
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Appid: 29789 unique values
# Name: 29779 unique values
# Type: 6 unique values
# ReleaseDate: 4416 unique values
# Genres: 1185 unique values
# Developers: 14777 unique values
# Publishers: 11238 unique values
# Description: 29651 unique values
# price: 452 unique values
# Thumbnail: 29786 unique values
# Tags: 24682 unique values
# ReviewScore: 10 unique values
# PositiveReview: 3766 unique values
# NegativeReview: 1668 unique values
# OsRequirement: 4027 unique values
# MemoryRequirement: 399 unique values
# CpuRequirement: 8430 unique values
# Rank: 16719 unique values

# %%
df["Genres"].unique()
# Out:
# array(['Action,Adventure', 'Action,Free To Play', 'Action', ...,
#        'Casual,Free To Play,Simulation,Sports',
#        'Casual,Indie,Massively Multiplayer,Racing,Simulation,Sports,Early Access',
#        'Sexual Content,Nudity,Casual,Indie,RPG'],
#       shape=(1186,), dtype=object)

# %%
df.head(5)
# Out:
#      Appid                            Name  Type   ReleaseDate  \
# 0  3764200           Resident Evil Requiem  game  Feb 26, 2026
# 1      730                Counter-Strike 2  game  Aug 21, 2012
# 2  1808500                     ARC Raiders  game  Oct 30, 2025
# 3   359550  Tom Clancy's Rainbow Six Siege  game   Dec 1, 2015
# 4  1172470                   Apex Legends™  game   Nov 4, 2020
#
#                           Genres        Developers        Publishers  \
# 0               Action,Adventure  CAPCOM Co., Ltd.  CAPCOM Co., Ltd.
# 1            Action,Free To Play             Valve             Valve
# 2                         Action    Embark Studios    Embark Studios
# 3            Action,Free To Play  Ubisoft Montreal           Ubisoft
# 4  Action,Adventure,Free To Play           Respawn   Electronic Arts
#
#                                          Description   price  \
# 0  Resident Evil Requiem Deluxe Edition Resident ...  69.99$
# 1  For over two decades, Counter-Strike has offer...      0$
# 2  ARC Raiders Deluxe Edition ARC Raiders Deluxe ...  39.99$
# 3  Season 11 Year 1 Overview Year 11 Roadmap Free...      0$
# 4  Apex Legends: Breach About the Game Conquer wi...      0$
#
#                                            Thumbnail  \
# 0  https://shared.akamai.steamstatic.com/store_it...
# 1  https://shared.akamai.steamstatic.com/store_it...
# 2  https://shared.akamai.steamstatic.com/store_it...
# 3  https://shared.akamai.steamstatic.com/store_it...
# 4  https://shared.akamai.steamstatic.com/store_it...
#
#                                                 Tags  ReviewScore  \
# 0                                                NaN            9
# 1  FPS,Shooter,Multiplayer,Competitive,Action,Tea...            8
# 2  Extraction Shooter,Multiplayer,PvP,PvE,Third-P...            8
# 3                                                NaN            8
# 4  Free to Play,Multiplayer,Battle Royale,FPS,Sho...            6
#
#    PositiveReview  NegativeReview                               OsRequirement  \
# 0           23715             793                                         NaN
# 1         1214897          202393                                 Windows® 10
# 2          149531           23194  Windows 10 or later 64-bit (latest update)
# 3          522886          106839                                         NaN
# 4             820             216                           64-bit Windows 10
#
#   MemoryRequirement                                     CpuRequirement  Rank
# 0               NaN                                                NaN     1
# 1          8 GB RAM  4 hardware CPU threads - Intel® Core™ i5 750 o...     2
# 2         12 GB RAM  Intel Core i5-6600K or AMD Ryzen R5 1600 proce...     3
# 3               NaN                                                NaN     4
# 4          6 GB RAM  AMD FX 4350 or Equivalent, Intel Core i3 6300 ...     5

# %%
from itertools import combinations
from collections import Counter

pairs = Counter()

for row in df['Tags'].dropna():
    t = row.split(',')
    pairs.update(combinations(t,2))

pairs.most_common(20)
# Out:
# [(('Adventure', 'Singleplayer'), 5855),
#  (('Indie', 'Singleplayer'), 5520),
#  (('Action', 'Singleplayer'), 5137),
#  (('Casual', 'Singleplayer'), 4914),
#  (('Simulation', 'Singleplayer'), 4267),
#  (('2D', 'Singleplayer'), 4247),
#  (('Adventure', 'Indie'), 3637),
#  (('Singleplayer', 'Indie'), 3521),
#  (('Action', 'Adventure'), 3458),
#  (('Action', 'Indie'), 3428),
#  (('Strategy', 'Singleplayer'), 3394),
#  (('Casual', 'Indie'), 3206),
#  (('Story Rich', 'Singleplayer'), 3036),
#  (('RPG', 'Singleplayer'), 3030),
#  (('Puzzle', 'Singleplayer'), 2831),
#  (('Atmospheric', 'Singleplayer'), 2800),
#  (('Adventure', 'Atmospheric'), 2677),
#  (('Adventure', 'Story Rich'), 2672),
#  (('Pixel Graphics', 'Singleplayer'), 2639),
#  (('Cute', 'Singleplayer'), 2611)]
