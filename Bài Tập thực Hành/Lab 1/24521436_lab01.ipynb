# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Phần ví dụ

# %%
df = pd.read_csv('C:/Users/nguye/SteamCrawler/Bài Tập thực Hành/Lab 1/Data/covid_19_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306429 entries, 0 to 306428
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              306429 non-null  int64
#  1   ObservationDate  306429 non-null  object
#  2   Province/State   228326 non-null  object
#  3   Country/Region   306429 non-null  object
#  4   Last Update      306429 non-null  object
#  5   Confirmed        306429 non-null  float64
#  6   Deaths           306429 non-null  float64
#  7   Recovered        306429 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 18.7+ MB

# %%
print("số lượng cột trong dataframe là: ", df.shape[1])
# Out:
# số lượng cột trong dataframe là:  8

# %%
print("Số lượng dòng trong dataframe là: ", df.shape[0])
# Out:
# Số lượng dòng trong dataframe là:  306429

# %%
df.head(10)
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
# 5    6      01/22/2020      Guangdong  Mainland China  1/22/2020 17:00
# 6    7      01/22/2020        Guangxi  Mainland China  1/22/2020 17:00
# 7    8      01/22/2020        Guizhou  Mainland China  1/22/2020 17:00
# 8    9      01/22/2020         Hainan  Mainland China  1/22/2020 17:00
# 9   10      01/22/2020          Hebei  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# ...

# %%
country_corona = df['Country/Region'].unique()
country_corona.shape
# Out:
# (229,)

# %%
maxConfirmedCases = df['Confirmed'].max()
print(maxConfirmedCases)
# Out:
# 5863138.0

# %%
Corona_China = df[df['Country/Region'] == 'Mainland China']
display(Corona_China)
# Out:
#            SNo ObservationDate Province/State  Country/Region  \
# 0            1      01/22/2020          Anhui  Mainland China
# 1            2      01/22/2020        Beijing  Mainland China
# 2            3      01/22/2020      Chongqing  Mainland China
# 3            4      01/22/2020         Fujian  Mainland China
# 4            5      01/22/2020          Gansu  Mainland China
# ...        ...             ...            ...             ...
# 306340  306341      05/29/2021          Tibet  Mainland China
# 306368  306369      05/29/2021        Unknown  Mainland China
# 306412  306413      05/29/2021       Xinjiang  Mainland China
# 306420  306421      05/29/2021         Yunnan  Mainland China
# 306426  306427      05/29/2021       Zhejiang  Mainland China
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# 1           1/22/2020 17:00       14.0     0.0        0.0
# ...

# %%
maxStateConfirmedCorona = df[df['Confirmed'] == maxConfirmedCases]["Province/State"]
display(maxStateConfirmedCorona)
# Out:
# 298068    NaN
# Name: Province/State, dtype: object

# %%
df['ObservationDate'] = pd.to_datetime(df["ObservationDate"])
df_jan = df[(df['ObservationDate'] >= "2020-01-01") & (df['ObservationDate'] <= "2020-01-31")]
display(df_jan)
# Out:
#      SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0      1      2020-01-22          Anhui  Mainland China  1/22/2020 17:00
# 1      2      2020-01-22        Beijing  Mainland China  1/22/2020 17:00
# 2      3      2020-01-22      Chongqing  Mainland China  1/22/2020 17:00
# 3      4      2020-01-22         Fujian  Mainland China  1/22/2020 17:00
# 4      5      2020-01-22          Gansu  Mainland China  1/22/2020 17:00
# ..   ...             ...            ...             ...              ...
# 508  509      2020-01-31            NaN     Philippines  1/31/2020 23:59
# 509  510      2020-01-31            NaN           India  1/31/2020 23:59
# 510  511      2020-01-31            NaN          Sweden  1/31/2020 23:59
# 511  512      2020-01-31        Unknown           China  1/31/2020 23:59
# 512  513      2020-01-31            NaN        Kiribati  1/31/2020 23:59
#
#      Confirmed  Deaths  Recovered
# 0          1.0     0.0        0.0
# ...

# %% [markdown]
# ### b) Tìm dữ liệu về số ca lây nhiễm tại Vietnam (Country.Region == 'Vietnam') và lưu vào biến coronaVietnam

# %%
coronaVietNam = df[df["Country/Region"] == 'Vietnam']
display(coronaVietNam)
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 81          82      2020-01-23            NaN        Vietnam
# 127        128      2020-01-24            NaN        Vietnam
# 170        171      2020-01-25            NaN        Vietnam
# 218        219      2020-01-26            NaN        Vietnam
# 267        268      2020-01-27            NaN        Vietnam
# ...        ...             ...            ...            ...
# 302771  302772      2021-05-25            NaN        Vietnam
# 303536  303537      2021-05-26            NaN        Vietnam
# 304301  304302      2021-05-27            NaN        Vietnam
# 305066  305067      2021-05-28            NaN        Vietnam
# 305831  305832      2021-05-29            NaN        Vietnam
#
#                 Last Update  Confirmed  Deaths  Recovered
# 81            1/23/20 17:00        2.0     0.0        0.0
# 127           1/24/20 17:00        2.0     0.0        0.0
# ...

# %% [markdown]
# ### c) Tìm dữ liệu về số ca lây nhiễm tại Việt Nam trong tháng 02 năm 2021.

# %%
coronaVietNamFeb = coronaVietNam[(coronaVietNam["ObservationDate"] >= "2021-2-1") & (coronaVietNam['ObservationDate'] <= "2021-2-28")]
display(coronaVietNamFeb)
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 216326  216327      2021-02-01            NaN        Vietnam
# 217091  217092      2021-02-02            NaN        Vietnam
# 217856  217857      2021-02-03            NaN        Vietnam
# 218621  218622      2021-02-04            NaN        Vietnam
# 219386  219387      2021-02-05            NaN        Vietnam
# 220151  220152      2021-02-06            NaN        Vietnam
# 220916  220917      2021-02-07            NaN        Vietnam
# 221681  221682      2021-02-08            NaN        Vietnam
# 222446  222447      2021-02-09            NaN        Vietnam
# 223211  223212      2021-02-10            NaN        Vietnam
# 223976  223977      2021-02-11            NaN        Vietnam
# 224741  224742      2021-02-12            NaN        Vietnam
# 225506  225507      2021-02-13            NaN        Vietnam
# 226271  226272      2021-02-14            NaN        Vietnam
# ...

# %% [markdown]
# ### d) In ra số dữ liệu về ca lây nhiễm nhiều nhất trong khoảng tháng 01 và 02 tại Việt Nam (Lấy năm 2021).

# %%
coronaVietNamJF = coronaVietNam[(coronaVietNam["ObservationDate"] >= "2021-1-1") & (coronaVietNam['ObservationDate'] <= "2021-2-28")]
maxConfirmedVietNamJF = coronaVietNamJF['Confirmed'].max()
display(coronaVietNamJF[coronaVietNamJF['Confirmed'] == maxConfirmedVietNamJF])
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 236981  236982      2021-02-28            NaN        Vietnam
#
#                 Last Update  Confirmed  Deaths  Recovered
# 236981  2021-04-02 15:13:53     2448.0    35.0     1876.0

# %% [markdown]
# ### e) Thực hiện tương tự câu d) cho Indonesia và Philipine.

# %%
# Indonesia 
coronaIndonesiaJF = df[(df["ObservationDate"] >= "2021-1-1") & (df['ObservationDate'] <= "2021-2-28") & (df["Country/Region"] == "Indonesia")]
maxConfirmedIndonesiaJF = coronaIndonesiaJF['Confirmed'].max()
display(coronaIndonesiaJF[coronaIndonesiaJF['Confirmed'] == maxConfirmedIndonesiaJF])
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 236884  236885      2021-02-28            NaN      Indonesia
#
#                 Last Update  Confirmed   Deaths  Recovered
# 236884  2021-04-02 15:13:53  1334634.0  36166.0  1142703.0

# %%
# Philipine
coronaPhilipineJF = df[(df["ObservationDate"] >= "2021-1-1") & (df['ObservationDate'] <= "2021-2-28") & (df["Country/Region"] == "Philippines")]
maxConfirmedPhilipineJF = coronaPhilipineJF['Confirmed'].max()
display(coronaPhilipineJF[coronaPhilipineJF['Confirmed'] == maxConfirmedPhilipineJF])
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 236936  236937      2021-02-28            NaN    Philippines
#
#                 Last Update  Confirmed   Deaths  Recovered
# 236936  2021-04-02 15:13:53   576352.0  12318.0   534271.0

# %% [markdown]
# ### e) In ra dữ liệu về ca nhiễm ghi nhân (Confirmed) của Trung Quốc trong khoảng thời gian từ 01/02/2021 cho đến 15/02/2021. In ra màn hình sử dụng lệnh print().

# %%
display(Corona_China[(df['ObservationDate'] >= "2020-01-01") & (df['ObservationDate'] <= "2020-01-31")][["Confirmed", "ObservationDate"]])
# Out:
# C:\Users\nguye\AppData\Local\Temp\ipykernel_38076\861609471.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   display(Corona_China[(df['ObservationDate'] >= "2020-01-01") & (df['ObservationDate'] <= "2020-01-31")][["Confirmed", "ObservationDate"]])
#      Confirmed ObservationDate
# 0          1.0      01/22/2020
# 1         14.0      01/22/2020
# 2          6.0      01/22/2020
# 3          1.0      01/22/2020
# 4          0.0      01/22/2020
# ..         ...             ...
# 475       20.0      01/31/2020
# 476       17.0      01/31/2020
# 477       14.0      01/31/2020
# 480        8.0      01/31/2020
# 482        1.0      01/31/2020
#
# [304 rows x 2 columns]

# %% [markdown]
# ### f) Thống kê số lượng record theo từng tỉnh của Trung Quốc trong tháng 02/2021. Gợi ý: Dùng hàm table(). Đếm từng dòng theo từng tỉnh.

# %%
All_Corona_China = df[df["Country/Region"].str.contains("China")]
AllcoronaChinaFeb = All_Corona_China[(All_Corona_China["ObservationDate"] >= "2021-02-01") & (All_Corona_China["ObservationDate"] <= "2021-02-28")]
coronaChinaFebProvince = AllcoronaChinaFeb.groupby('Province/State').size().reset_index(name = "Count")
display(coronaChinaFebProvince)
# Out:
#     Province/State  Count
# 0            Anhui     28
# 1          Beijing     28
# 2        Chongqing     28
# 3           Fujian     28
# 4            Gansu     28
# 5        Guangdong     28
# 6          Guangxi     28
# 7          Guizhou     28
# 8           Hainan     28
# 9            Hebei     28
# 10    Heilongjiang     28
# 11           Henan     28
# 12           Hubei     28
# 13           Hunan     28
# 14  Inner Mongolia     28
# 15         Jiangsu     28
# 16         Jiangxi     28
# 17           Jilin     28
# 18        Liaoning     28
# 19         Ningxia     28
# 20         Qinghai     28
# 21         Shaanxi     28
# 22        Shandong     28
# 23        Shanghai     28
# 24          Shanxi     28
# 25         Sichuan     28
# 26         Tianjin     28
# 27           Tibet     28
# 28         Unknown     28
# 29        Xinjiang     28
# 30          Yunnan     28
# 31        Zhejiang     28

# %% [markdown]
# ### g) Đếm số lượng ca nhiễm mới theo từng tỉnh của Trung Quốc trong tháng 02/2021.
# Gợi ý: Sử dụng vòng lặp trong R như sau: với mỗi vòng lặp theo thuộc tính tỉnh (Province.State), lấy ra tên tỉnh. Ứng với từng tên tỉnh, lấy số ca nhiễm được ghi nhận (Confirmed) của ngày cuối cùng trong tháng trừ đi cho số ca nhiễm được ghi nhận (Confirmed) của ngày đầu tiên trong tháng.

# %%
res = []
for province, group in All_Corona_China.groupby("Province/State"):
    All_Corona_China.sort_values("ObservationDate")
    start = group.iloc[0]["Confirmed"]
    end = group.iloc[-1]["Confirmed"]
    res.append({"Province" : province, "New confirmed":(end - start).astype(int)})
NewConfirmedFebChina = pd.DataFrame(res)
display(NewConfirmedFebChina)
# Out:
#           Province  New confirmed
# 0            Anhui           1003
# 1          Beijing           1045
# 2        Chongqing            592
# 3           Fujian            619
# 4            Gansu            194
# 5        Guangdong           2406
# 6          Guangxi            273
# 7          Guizhou            146
# 8           Hainan            184
# 9            Hebei           1316
# 10    Heilongjiang           1612
# 11           Henan           1309
# 12           Hubei          67715
# 13           Hunan           1047
# 14  Inner Mongolia            387
# 15         Jiangsu            725
# 16         Jiangxi            935
# 17           Jilin            573
# 18        Liaoning            423
# 19         Ningxia             75
# 20         Qinghai             18
# 21         Shaanxi            616
# 22        Shandong            881
# 23        Shanghai           2084
# 24          Shanxi            252
# 25         Sichuan           1020
# ...

# %% [markdown]
# ### h) Tìm dữ liệu ca tử vong của Trung Quốc trong khoảng thời gian từ 01/02/2021 cho đến 15/02/2021. In ra màn hình sử dụng lệnh print().

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306429 entries, 0 to 306428
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              306429 non-null  int64
#  1   ObservationDate  306429 non-null  datetime64[ns]
#  2   Province/State   228326 non-null  object
#  3   Country/Region   306429 non-null  object
#  4   Last Update      306429 non-null  object
#  5   Confirmed        306429 non-null  float64
#  6   Deaths           306429 non-null  float64
#  7   Recovered        306429 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 18.7+ MB

# %%
CoronaChinaHalfFeb = All_Corona_China[(All_Corona_China["ObservationDate"] >= '2021-02-01') & (All_Corona_China["ObservationDate"] <= '2021-02-15')]
display(CoronaChinaHalfFeb[["Province/State", "Country/Region", "Deaths"]])
# Out:
#        Province/State  Country/Region  Deaths
# 216353          Anhui  Mainland China     6.0
# 216387        Beijing  Mainland China     9.0
# 216437      Chongqing  Mainland China     6.0
# 216479         Fujian  Mainland China     1.0
# 216484          Gansu  Mainland China     2.0
# ...               ...             ...     ...
# 227545          Tibet  Mainland China     0.0
# 227573        Unknown  Mainland China     0.0
# 227617       Xinjiang  Mainland China     3.0
# 227625         Yunnan  Mainland China     2.0
# 227631       Zhejiang  Mainland China     1.0
#
# [480 rows x 3 columns]

# %%
coronaVietNamDaily = coronaVietNam.groupby("ObservationDate")["Confirmed"].sum().reset_index().sort_values("ObservationDate")
coronaVietNamDaily["NewConfirmedDaily"] = coronaVietNamDaily["Confirmed"].diff().fillna(0)
display(coronaVietNamDaily)
# Out:
#     ObservationDate  Confirmed  NewConfirmedDaily
# 0        2020-01-23        2.0                0.0
# 1        2020-01-24        2.0                0.0
# 2        2020-01-25        2.0                0.0
# 3        2020-01-26        2.0                0.0
# 4        2020-01-27        2.0                0.0
# ..              ...        ...                ...
# 488      2021-05-25     5931.0              527.0
# 489      2021-05-26     6086.0              155.0
# 490      2021-05-27     6356.0              270.0
# 491      2021-05-28     6396.0               40.0
# 492      2021-05-29     6908.0              512.0
#
# [493 rows x 3 columns]

# %%
coronaVietNamDaily2020 = coronaVietNamDaily[(coronaVietNamDaily["ObservationDate"] >= "2020-05-01") & (coronaVietNamDaily["ObservationDate"] <= "2020-05-31")]
coronaVietNamDaily2021 = coronaVietNamDaily[(coronaVietNamDaily["ObservationDate"] >= "2021-05-01") & (coronaVietNamDaily["ObservationDate"] <= "2021-05-31")]

# %%
plt.figure(figsize=(20,12))
plt.plot(coronaVietNamDaily2020["ObservationDate"].dt.day, coronaVietNamDaily2020["NewConfirmedDaily"])
plt.plot(coronaVietNamDaily2021["ObservationDate"].dt.day, coronaVietNamDaily2021["NewConfirmedDaily"])

# %% [markdown]
# ### k. Vẽ biểu đồ về số ca lây nhiễm nhiều nhất của 3 quốc gia: Vietnam, Indonesia và Philippine trong 2 tháng gồm 01 và tháng 02 năm 2021.

# %%
countries = ["Vietnam", "Indonesia", "Philippines"]
coronaJanVIP = df[(df["ObservationDate"] >= "2021-01-01") & (df["ObservationDate"] <= "2021-01-31") & (df["Country/Region"].isin(countries))]
coronaFebVIP = df[(df["ObservationDate"] >= "2021-01-01") & (df["ObservationDate"] <= "2021-02-28") & (df["Country/Region"].isin(countries))]
def Confirmed_daily(df):
    df_daily = df.groupby(["Country/Region","ObservationDate"])["Confirmed"].sum().reset_index()
    df_daily["NewConfirmedDaily"] = df_daily.groupby("Country/Region")["Confirmed"].diff().fillna(0)
    return df_daily.groupby("Country/Region")["NewConfirmedDaily"].max()
maxJanVIP = Confirmed_daily(coronaJanVIP)
maxFebVIP = Confirmed_daily(coronaFebVIP)

plt.figure(figsize = (20,12))
x = np.arange(len(countries))
width = 0.35
plt.bar(x - width/2, maxJanVIP, width, label="Tháng 1/2021")
plt.bar(x + width/2, maxFebVIP, width, label="Tháng 2/2021")
plt.xticks(x, countries)
plt.legend()
plt.show()
